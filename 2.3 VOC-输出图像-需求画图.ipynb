# %%
import matplotlib.pyplot as plt
import numpy as np
import platform
import pandas as pd
import os
import re
from datetime import datetime
import spacy
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizer
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# 根据操作系统设置合适的中文字体
system = platform.system()
if system == 'Darwin':  # macOS
    plt.rcParams['font.sans-serif'] = ['Arial Unicode MS', 'Heiti TC', 'PingFang HK', 'Apple Color Emoji']
elif system == 'Windows':
    plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei', 'SimSun']
else:  # Linux或其他
    plt.rcParams['font.sans-serif'] = ['DejaVu Sans', 'WenQuanYi Micro Hei', 'WenQuanYi Zen Hei']

# 正常显示负号
plt.rcParams['axes.unicode_minus'] = False

print(f"当前操作系统: {system}")
print(f"当前字体设置: {plt.rcParams['font.sans-serif']}")

# 获取Excel文件名
import glob
data_folder = "./Data"
voc_files = glob.glob(os.path.join(data_folder, "*VOC数据.xlsx"))

if not voc_files:
    print(f"在 {data_folder} 文件夹中未找到任何以'VOC数据.xlsx'结尾的文件")
    # 可以根据需要添加错误处理
else:
    # 如果找到多个匹配的文件，打印列表并使用第一个
    if len(voc_files) > 1:
        print(f"在 {data_folder} 文件夹中找到多个VOC数据文件:")
        for i, file in enumerate(voc_files):
            print(f"{i+1}. {os.path.basename(file)}")
        print(f"将使用第一个文件: {os.path.basename(voc_files[0])}")
    
    # 获取完整文件路径
    excel_filepath = voc_files[0]
    
    # 提取文件名（不含路径和扩展名）
    excel_filename = os.path.basename(excel_filepath)
    base_filename = os.path.splitext(excel_filename)[0]
    
    print(f"找到VOC数据文件: {excel_filename}")
    print(f"提取的文件名: {base_filename}")

# 新路径设置
output_dir = "生成结果/needs_analysis/"
os.makedirs(output_dir, exist_ok=True)

# 需求分析文本文件路径
needs_txt_file = os.path.join(output_dir, f'{base_filename}_用户需求象限分析_完整列表.txt')
output_filename = os.path.join(output_dir, f'{base_filename}_用户需求四象限分析_综合得分版.png')

# 创建空白图和报告的辅助函数
def create_empty_chart(message="没有相关需求数据"):
    plt.figure(figsize=(16, 14))
    plt.text(0.5, 0.5, message, 
             fontsize=30, ha='center', va='center',
             bbox=dict(facecolor='white', alpha=0.8, boxstyle='round,pad=1'))
    
    # 设置坐标轴和标题
    plt.xlabel('需求优先级\n（负向：次要 | 正向：重要）', fontsize=14)
    plt.ylabel('市场需求度\n（提及频率与用户关注度）', fontsize=14)
    plt.title(f'{base_filename} - 未被满足的需求四象限分析', fontsize=18)
    
    # 隐藏坐标轴刻度
    plt.xticks([])
    plt.yticks([])
    
    # 保存图片
    plt.savefig(output_filename, dpi=300, bbox_inches='tight')
    print(f"\n空白图表已保存为: {output_filename}")
    
    plt.show()

# 创建空白报告函数
def create_empty_report(message="没有找到任何用户需求数据"):
    with open(needs_txt_file, 'w', encoding='utf-8') as f:
        f.write(f"# {base_filename} 用户需求象限分析 - 完整列表\n")
        f.write(f"生成时间: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
        f.write(f"{message}\n")
    
    print(f"\n空白报告已保存到: {needs_txt_file}")

# 从目录中找到匹配的分析结果文件
csv_files = [f for f in os.listdir(output_dir) if f.startswith('refined_') and f.endswith('_needs_analysis.xlsx')]
if csv_files:
    csv_file = os.path.join(output_dir, csv_files[0])  # 使用找到的第一个匹配文件
    print(f"使用找到的需求分析文件: {csv_file}")
else:
    # 如果找不到匹配文件，使用指定的默认路径
    csv_file = os.path.join(output_dir, f"{base_filename}_rating_0_to_5_length_10_to_200_words_needs_analysis.xlsx")
    print(f"未找到匹配文件，将使用默认路径: {csv_file}")

# 读取CSV文件
try:
    data = pd.read_excel(csv_file)
    print(f"成功读取数据，共{len(data)}条记录")
    
    # 检查是否有数据
    if len(data) == 0:
        print("警告: 数据文件中没有记录")
        create_empty_chart()
        create_empty_report()
        import sys
        sys.exit(0)
        
except Exception as e:
    print(f"读取Excel文件失败: {e}")
    # 尝试不同的编码
    try_loading = False
    for encoding in ['utf-8', 'utf-8-sig', 'gbk', 'latin1']:
        try:
            data = pd.read_csv(csv_file, encoding=encoding)
            print(f"使用{encoding}编码成功读取数据，共{len(data)}条记录")
            try_loading = True
            
            # 检查是否有数据
            if len(data) == 0:
                print("警告: 数据文件中没有记录")
                create_empty_chart()
                create_empty_report()
                import sys
                sys.exit(0)
                
            break
        except:
            continue
    
    if not try_loading:
        print("无法读取数据文件，请检查文件路径和格式")
        create_empty_chart("无法读取数据文件")
        create_empty_report("无法读取数据文件，请检查文件路径和格式。")
        import sys
        sys.exit(1)

# 确保数据包含必要的列
required_columns = ['Need', 'Frequency', 'Importance_Score']
missing_columns = [col for col in required_columns if col not in data.columns]

if missing_columns:
    print(f"警告: 数据中缺少必要的列: {missing_columns}")
    create_empty_chart("数据格式不正确")
    create_empty_report(f"数据中缺少必要的列: {missing_columns}，请检查数据格式。")
    import sys
    sys.exit(1)

if '需求' not in data.columns and '卖点' in data.columns:
    # 兼容处理：如果没有"需求"列但有"卖点"列，则重命名
    data.rename(columns={'卖点': '需求'}, inplace=True)

# 数据预处理
try:
    data['提及频率_num'] = data['Frequency'].astype('float')*100
except Exception as e:
    print(f"转换提及频率失败: {e}")
    data['提及频率_num'] = 1.0  # 设置默认值

try:
    data['重要性分数'] = data['Importance_Score']
except Exception as e:
    print(f"转换重要性分数失败: {e}")
    data['重要性分数'] = 1.0  # 设置默认值

# 打印数据概览
print("\n数据概览:")
print(f"总行数: {len(data)}")
print(f"需求列: {data['Need'].nunique()} 个唯一值")
print(f"重要性分数范围: {data['重要性分数'].min()} 到 {data['重要性分数'].max()}")
print(f"提及频率范围: {data['提及频率_num'].min()} 到 {data['提及频率_num'].max()}")

# 查看相关性
try:
    corr = data['重要性分数'].corr(data['提及频率_num'])
    print(f"\n重要性分数与提及频率的相关系数: {corr:.4f}")
except Exception as e:
    print(f"计算相关性失败: {e}")
    corr = 0

# 对数据分布进行对数变换，使长尾分布更加正常化
data['log_importance'] = np.log1p(data['重要性分数'])
data['log_frequency'] = np.log1p(data['提及频率_num'])

# 变换后的分布
print("\n对数变换后的分布:")
print(f"Log重要性分数范围: {data['log_importance'].min():.2f} 到 {data['log_importance'].max():.2f}")
print(f"Log提及频率范围: {data['log_frequency'].min():.2f} 到 {data['log_frequency'].max():.2f}")

# 尝试不同的象限划分方法
# 1. 基于对数变换后的分位数划分
x_log_median = data['log_importance'].median()
y_log_median = data['log_frequency'].median()

print("\n方法1: 对数变换后的中位数划分")
print(f"Log重要性分数中位数: {x_log_median:.2f}")
print(f"Log提及频率中位数: {y_log_median:.2f}")

data['quadrant_log_median'] = 0
data.loc[(data['log_importance'] >= x_log_median) & (data['log_frequency'] >= y_log_median), 'quadrant_log_median'] = 1
data.loc[(data['log_importance'] < x_log_median) & (data['log_frequency'] >= y_log_median), 'quadrant_log_median'] = 2
data.loc[(data['log_importance'] < x_log_median) & (data['log_frequency'] < y_log_median), 'quadrant_log_median'] = 3
data.loc[(data['log_importance'] >= x_log_median) & (data['log_frequency'] < y_log_median), 'quadrant_log_median'] = 4

# 2. 基于原始数据的特定分位数划分
# 使用25%/75%作为分割点
x_p25 = np.percentile(data['重要性分数'], 25)
x_p75 = np.percentile(data['重要性分数'], 75)
y_p25 = np.percentile(data['提及频率_num'], 25)
y_p75 = np.percentile(data['提及频率_num'], 75)

print("\n方法2: 25%/75%分位数划分")
print(f"重要性分数 25%分位: {x_p25:.2f}, 75%分位: {x_p75:.2f}")
print(f"提及频率 25%分位: {y_p25:.2f}, 75%分位: {y_p75:.2f}")

data['quadrant_quartile'] = 0
data.loc[(data['重要性分数'] >= x_p75) & (data['提及频率_num'] >= y_p75), 'quadrant_quartile'] = 1
data.loc[(data['重要性分数'] <= x_p25) & (data['提及频率_num'] >= y_p75), 'quadrant_quartile'] = 2
data.loc[(data['重要性分数'] <= x_p25) & (data['提及频率_num'] <= y_p25), 'quadrant_quartile'] = 3
data.loc[(data['重要性分数'] >= x_p75) & (data['提及频率_num'] <= y_p25), 'quadrant_quartile'] = 4
# 处理中间区域
middle_mask = ((data['重要性分数'] > x_p25) & (data['重要性分数'] < x_p75)) | ((data['提及频率_num'] > y_p25) & (data['提及频率_num'] < y_p75))
data.loc[middle_mask, 'quadrant_quartile'] = 5  # 中间区域标记为5

# 3. 使用K-means聚类将数据聚为4类，然后映射到象限
# 准备聚类用的特征
X = data[['log_importance', 'log_frequency']].values

# 检查数据量是否足够进行聚类
if len(data) >= 4:
    try:
        # 标准化
        X_std = (X - X.mean(axis=0)) / X.std(axis=0)
        X_std = np.nan_to_num(X_std)
        # 使用K-means聚类
        k = min(4, len(data))  # 如果数据量少于4，就使用数据量作为聚类数
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        clusters = kmeans.fit_predict(X_std)
        data['cluster'] = clusters

        # 获取聚类中心
        centers = kmeans.cluster_centers_
        # 还原聚类中心（去标准化）
        centers = centers * X.std(axis=0) + X.mean(axis=0)

        # 计算每个聚类中心相对于整体中心的位置
        overall_center = X.mean(axis=0)
        relative_positions = centers - overall_center

        # 根据聚类中心的位置映射到象限
        cluster_to_quadrant = {}
        for i in range(k):
            # 获取相对位置
            rel_x, rel_y = relative_positions[i]
            # 确定象限
            if rel_x >= 0 and rel_y >= 0:
                cluster_to_quadrant[i] = 1  # 右上
            elif rel_x < 0 and rel_y >= 0:
                cluster_to_quadrant[i] = 2  # 左上
            elif rel_x < 0 and rel_y < 0:
                cluster_to_quadrant[i] = 3  # 左下
            else:  # rel_x >= 0 and rel_y < 0
                cluster_to_quadrant[i] = 4  # 右下

        print("\n方法3: K-means聚类映射到象限")
        print("聚类中心:")
        for i in range(k):
            print(f"聚类 {i}: 重要性={np.exp(centers[i, 0])-1:.2f}, 频率={np.exp(centers[i, 1])-1:.2f}, 映射到象限 {cluster_to_quadrant[i]}")

        # 将聚类结果映射到象限
        data['quadrant_kmeans'] = data['cluster'].map(cluster_to_quadrant)
        
        # 如果聚类数量小于4，确保四个象限都有值
        if k < 4:
            print("警告: 聚类数量小于4，某些象限可能没有被分配数据点")
            # 确保所有象限都有一个默认值
            for q in range(1, 5):
                if q not in cluster_to_quadrant.values():
                    # 找到没有使用的象限，并将第一个聚类的部分数据点分配给它
                    first_cluster = data['cluster'].iloc[0]
                    n_rows = sum(data['cluster'] == first_cluster)
                    # 只有当有足够多的点时才分配
                    if n_rows > 1:
                        data.loc[data['cluster'] == first_cluster].iloc[:1, data.columns.get_loc('quadrant_kmeans')] = q
    except Exception as e:
        print(f"K-means聚类失败: {e}")
        print("将使用简单的中位数划分方法代替K-means")
        # 使用简单的中位数划分作为备选
        data['quadrant_kmeans'] = data['quadrant_log_median']
else:
    print("数据量不足以执行K-means聚类（需要至少4个数据点）")
    print("将使用简单的中位数划分方法代替")
    # 复制中位数划分结果
    data['quadrant_kmeans'] = data['quadrant_log_median']
    # 为少量数据均匀分配象限
    if len(data) == 1:
        data.iloc[0, data.columns.get_loc('quadrant_kmeans')] = 1  # 单个点放在第一象限
    elif len(data) == 2:
        data.iloc[0, data.columns.get_loc('quadrant_kmeans')] = 1  # 第一点放在第一象限
        data.iloc[1, data.columns.get_loc('quadrant_kmeans')] = 3  # 第二点放在第三象限
    elif len(data) == 3:
        data.iloc[0, data.columns.get_loc('quadrant_kmeans')] = 1  # 第一点放在第一象限
        data.iloc[1, data.columns.get_loc('quadrant_kmeans')] = 2  # 第二点放在第二象限
        data.iloc[2, data.columns.get_loc('quadrant_kmeans')] = 4  # 第三点放在第四象限

# 4. 主成分分析方法 - 基于原始数据分布的主方向
try:
    data['frequency'] = data['提及频率_num']/100

    # 使用对数变换调整频率，减少极端高频值的过度影响
    data['adjusted_frequency'] = np.log1p(data['frequency'])  # log1p = log(1+x)

    # 如果数据点超过1个，计算回归线
    if len(data) > 1:
        try:
            slope, intercept = np.polyfit(data['log_importance'], data['adjusted_frequency'], 1)
            print("\n改进方法: 基于调整频率的主成分划分")
            print(f"回归线: adjusted_frequency = {slope:.4f} * log_importance + {intercept:.4f}")

            # 计算每个点到回归线的垂直距离
            data['distance_to_regression'] = data['adjusted_frequency'] - (slope * data['log_importance'] + intercept)

            # 将点分为回归线上/下两部分
            above_regression = data['distance_to_regression'] >= 0
            below_regression = data['distance_to_regression'] < 0

            # 计算投影到回归线上的位置
            data['projection'] = (data['log_importance'] + slope * data['adjusted_frequency']) / (1 + slope**2)

            # 找到投影的中位数，用于左右划分
            projection_median = data['projection'].median()
            left_half = data['projection'] < projection_median
            right_half = data['projection'] >= projection_median

            # 组合得到象限
            data['quadrant_pca'] = 0
            data.loc[right_half & above_regression, 'quadrant_pca'] = 1  # 右上
            data.loc[left_half & above_regression, 'quadrant_pca'] = 2   # 左上
            data.loc[left_half & below_regression, 'quadrant_pca'] = 3   # 左下
            data.loc[right_half & below_regression, 'quadrant_pca'] = 4  # 右下
        except Exception as e:
            print(f"回归线计算失败: {e}")
            print("将使用简单的中位数划分方法代替")
            data['quadrant_pca'] = data['quadrant_log_median']
    else:
        print("数据点不足以计算回归线（需要至少2个点）")
        # 如果只有一个数据点，直接分配到第一象限
        data['quadrant_pca'] = 1
except Exception as e:
    print(f"主成分分析方法失败: {e}")
    data['quadrant_pca'] = data['quadrant_log_median']

# 5. 双阈值多分位数方法
try:
    # 根据数据量进行不同的分位数计算
    if len(data) >= 10:
        # 对于数据量充足的情况使用多个阈值
        x_thresholds = [np.percentile(data['重要性分数'], p) for p in [10, 50, 90]]
        y_thresholds = [np.percentile(data['提及频率_num'], p) for p in [10, 50, 90]]

        print("\n方法5: 多阈值分位数划分")
        print(f"重要性分数阈值: 10%={x_thresholds[0]:.2f}, 50%={x_thresholds[1]:.2f}, 90%={x_thresholds[2]:.2f}")
        print(f"提及频率阈值: 10%={y_thresholds[0]:.2f}, 50%={y_thresholds[1]:.2f}, 90%={y_thresholds[2]:.2f}")

        # 初始化为0
        data['quadrant_multi'] = 0

        # 右上象限 (1): 高重要性，高频率
        data.loc[(data['重要性分数'] >= x_thresholds[2]) & (data['提及频率_num'] >= y_thresholds[2]), 'quadrant_multi'] = 1

        # 左上象限 (2): 低重要性，高频率
        data.loc[(data['重要性分数'] <= x_thresholds[0]) & (data['提及频率_num'] >= y_thresholds[2]), 'quadrant_multi'] = 2

        # 左下象限 (3): 低重要性，低频率
        data.loc[(data['重要性分数'] <= x_thresholds[0]) & (data['提及频率_num'] <= y_thresholds[0]), 'quadrant_multi'] = 3

        # 右下象限 (4): 高重要性，低频率
        data.loc[(data['重要性分数'] >= x_thresholds[2]) & (data['提及频率_num'] <= y_thresholds[0]), 'quadrant_multi'] = 4

        # 处理中间区域：根据相关性判断最近的象限
        middle_mask = data['quadrant_multi'] == 0
        for idx in data[middle_mask].index:
            importance = data.loc[idx, '重要性分数']
            frequency = data.loc[idx, '提及频率_num']
            
            # 根据点相对于中心的位置确定象限
            if importance >= x_thresholds[1]:
                if frequency >= y_thresholds[1]:
                    data.loc[idx, 'quadrant_multi'] = 1  # 右上
                else:
                    data.loc[idx, 'quadrant_multi'] = 4  # 右下
            else:
                if frequency >= y_thresholds[1]:
                    data.loc[idx, 'quadrant_multi'] = 2  # 左上
                else:
                    data.loc[idx, 'quadrant_multi'] = 3  # 左下
    else:
        print("数据量不足以执行多阈值分位数划分（需要至少10个数据点）")
        # 使用简单的中位数划分替代
        data['quadrant_multi'] = data['quadrant_log_median']
except Exception as e:
    print(f"多阈值分位数方法失败: {e}")
    data['quadrant_multi'] = data['quadrant_log_median']

# 6. 强制平衡划分法 - 按数据点数量强制平均分配到四个象限
try:
    if len(data) >= 4:
        # 按重要性分数和提及频率各自排序，取排名前50%和后50%
        importance_median_rank = len(data) // 2
        frequency_median_rank = len(data) // 2

        # 获取排序后的索引
        importance_sorted_idx = data['重要性分数'].argsort()
        frequency_sorted_idx = data['提及频率_num'].argsort()

        # 根据排名确定高/低重要性和高/低频率
        high_importance = np.zeros(len(data), dtype=bool)
        high_frequency = np.zeros(len(data), dtype=bool)

        high_importance[importance_sorted_idx[importance_median_rank:]] = True
        high_frequency[frequency_sorted_idx[frequency_median_rank:]] = True

        # 组合得到象限
        data['quadrant_balanced'] = 0
        data.loc[high_importance & high_frequency, 'quadrant_balanced'] = 1  # 右上
        data.loc[(~high_importance) & high_frequency, 'quadrant_balanced'] = 2  # 左上
        data.loc[(~high_importance) & (~high_frequency), 'quadrant_balanced'] = 3  # 左下
        data.loc[high_importance & (~high_frequency), 'quadrant_balanced'] = 4  # 右下

        print("\n方法6: 强制平衡划分")
        print("基于数据点排名强制平均分配到四个象限")
    else:
        print("数据量不足以执行强制平衡划分（需要至少4个数据点）")
        # 如果只有1-3个数据点，则均匀分配到不同象限
        data['quadrant_balanced'] = 0
        if len(data) == 1:
            data.iloc[0, data.columns.get_loc('quadrant_balanced')] = 1  # 单个点放在第一象限
        elif len(data) == 2:
            data.iloc[0, data.columns.get_loc('quadrant_balanced')] = 1  # 第一点放在第一象限
            data.iloc[1, data.columns.get_loc('quadrant_balanced')] = 3  # 第二点放在第三象限
        elif len(data) == 3:
            data.iloc[0, data.columns.get_loc('quadrant_balanced')] = 1  # 第一点放在第一象限
            data.iloc[1, data.columns.get_loc('quadrant_balanced')] = 2  # 第二点放在第二象限
            data.iloc[2, data.columns.get_loc('quadrant_balanced')] = 4  # 第三点放在第四象限
except Exception as e:
    print(f"强制平衡划分方法失败: {e}")
    data['quadrant_balanced'] = data['quadrant_log_median']

# 检查所有方法的象限分布
methods = [
    ('对数中位数法', 'quadrant_log_median'),
    ('四分位数法', 'quadrant_quartile'),
    ('K-means聚类法', 'quadrant_kmeans'),
    ('主成分分析法', 'quadrant_pca'),
    ('多阈值分位数法', 'quadrant_multi'),
    ('强制平衡法', 'quadrant_balanced')
]

print("\n各方法象限分布对比:")
for method_name, column in methods:
    print(f"\n{method_name} 各象限分布:")
    
    # 排除中间区域的分析(如果有)
    if column == 'quadrant_quartile':
        valid_data = data[data[column] != 5]
        print(f"有效数据点: {len(valid_data)}/{len(data)}")
        value_counts = valid_data[column].value_counts().sort_index()
    else:
        value_counts = data[column].value_counts().sort_index()
    
    for q in range(1, 5):
        count = value_counts.get(q, 0)
        percentage = count / len(data) * 100 if len(data) > 0 else 0
        print(f"象限 {q}: {count} 项 ({percentage:.1f}%)")
    
    # 计算标准差，评估均衡性
    counts = [value_counts.get(q, 0) for q in range(1, 5)]
    std = np.std(counts)
    mean = np.mean(counts)
    cv = std / mean if mean > 0 else float('inf')  # 变异系数
    
    print(f"标准差: {std:.2f}, 均值: {mean:.2f}, 变异系数: {cv:.2f}")

# 选择最均衡的方法 - 使用变异系数(CV)最小的方法
method_stats = []
for method_name, column in methods:
    if column == 'quadrant_quartile':
        valid_data = data[data[column] != 5]
        value_counts = valid_data[column].value_counts()
    else:
        value_counts = data[column].value_counts()
    
    counts = [value_counts.get(q, 0) for q in range(1, 5)]
    std = np.std(counts)
    mean = np.mean(counts)
    cv = std / mean if mean > 0 else float('inf')
    
    has_all_quadrants = all(q in value_counts.index for q in range(1, 5))
    
    method_stats.append((method_name, column, cv, has_all_quadrants))

# 筛选出有所有象限的方法，按变异系数排序
valid_methods = [(name, col, cv) for name, col, cv, has_all in method_stats if has_all]

if valid_methods:
    best_method = min(valid_methods, key=lambda x: x[2])
    print(f"\n选择最均衡的方法: {best_method[0]} (变异系数: {best_method[2]:.2f})")
    data['quadrant'] = data[best_method[1]]
else:
    # 如果没有方法包含所有象限，选择CV最小的方法
    best_method = min(method_stats, key=lambda x: x[2])
    print(f"\n选择最均衡的方法: {best_method[0]} (变异系数: {best_method[2]:.2f}, 但并非所有象限都有数据)")
    data['quadrant'] = data[best_method[1]]
    
    # 对于数据量不足的情况，确保每个象限至少有一个数据点
    if len(data) >= 4:
        quadrants_present = set(data['quadrant'].unique())
        missing_quadrants = set(range(1, 5)) - quadrants_present
        
        # 如果缺少某些象限，从现有数据点复制
        if missing_quadrants and len(data) >= len(missing_quadrants):
            for i, q in enumerate(missing_quadrants):
                idx = data.index[i % len(data)]  # 使用模运算避免索引越界
                data.loc[idx, 'quadrant'] = q
                print(f"将索引为 {idx} 的数据点分配给缺失的象限 {q}")

print("\n最终选定方法各象限分布:")
for q in range(1, 5):
    q_count = len(data[data['quadrant'] == q])
    q_percent = q_count / len(data) * 100 if len(data) > 0 else 0
    print(f"象限 {q}: {q_count} 项 ({q_percent:.1f}%)")

# 计算原始重要性分数到"需求优先级"的映射
min_importance = data['重要性分数'].min()
max_importance = data['重要性分数'].max()
data['需求优先级'] = (data['重要性分数'] - min_importance) / (max_importance - min_importance) if max_importance > min_importance else 0.5

# 计算综合得分 - 结合重要性分数和提及频率
# 首先将提及频率归一化到0-1
min_freq = data['提及频率_num'].min()
max_freq = data['提及频率_num'].max()
data['归一化频率'] = (data['提及频率_num'] - min_freq) / (max_freq - min_freq) if max_freq > min_freq else 0.5

# 计算综合得分 = 0.6*需求优先级 + 0.4*提及频率
data['综合得分'] = 0.6 * data['需求优先级'] + 0.4 * data['归一化频率']

# 尝试加载NLP模型，对每个象限的内容进行语义处理
try:
    # 加载spaCy模型
    nlp = spacy.load("en_core_web_sm")
    print("\n成功加载spaCy模型")
    
    # 加载情感分析模型
    sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
    print("成功加载情感分析模型")
    
    # 使用预训练模型评估需求文本质量
    def evaluate_need_quality(text):
        """
        评估需求文本的质量，返回0-1之间的得分
        较高的分数表示文本更可能是有效的需求描述
        """
        if not isinstance(text, str) or len(text) < 3:
            return 0.0
        
        # 基本得分
        score = 0.5
        
        # 1. spaCy分析
        doc = nlp(text)
        
        # 检查是否包含产品相关名词
        product_entities = ["bag", "pocket", "space", "storage", "comfort", "design", "color", "style"]
        has_product_terms = any(term.lower() in text.lower() for term in product_entities)
        if has_product_terms:
            score += 0.2
        
        # 检查是否包含需求指示词
        need_terms = ["need", "want", "wish", "like", "prefer", "better", "improve", "should", "would", "could"]
        has_need_terms = any(term.lower() in text.lower() for term in need_terms)
        if has_need_terms:
            score += 0.2
            
        # 检查是否包含个人代词(可能表示用户需求)
        personal_pronouns = ["i", "my", "we", "our"]
        has_personal = any(token.text.lower() in personal_pronouns for token in doc)
        if has_personal:
            score += 0.1  # 对于需求分析，个人观点是正面的
        
        # 2. 情感分析
        try:
            sentiment_result = sentiment_analyzer(text)
            sentiment_label = sentiment_result[0]['label']
            sentiment_score = sentiment_result[0]['score']
            
            # 需求描述可能是正面或负面的，但明确的需求通常会有较高的情感得分
            if sentiment_score > 0.7:
                score += 0.1
        except:
            # 如果情感分析失败，不调整得分
            pass
        
        # 确保得分在0-1范围内
        return max(0.0, min(1.0, score))
    
    # 对每个象限分别评估文本质量
    print("\n评估各象限文本质量")
    quadrant_data = {}
    
    for q in range(1, 5):
        # 获取该象限的所有数据
        q_data = data[data['quadrant'] == q].copy()
        
        if len(q_data) > 0:
            # 应用评估函数
            q_data['文本质量'] = q_data['Need'].apply(evaluate_need_quality)
            
            # 按文本质量和提及频率排序
            q_data = q_data.sort_values(['文本质量', '提及频率_num'], ascending=[False, False])
            
            # 选择质量较好的前20个
            q_data = q_data.head(20)
            
            print(f"象限 {q}: 选择了 {len(q_data)} 个高质量文本")
            if len(q_data) > 0:
                print("示例:")
                for _, row in q_data.head(3).iterrows():
                    print(f"- {row['Need']} (质量: {row['文本质量']:.2f}, 提及频率: {row['Frequency']}, 重要性: {row['重要性分数']:.2f})")
        else:
            print(f"象限 {q}: 没有数据")
            
        quadrant_data[q] = q_data
    
    # 合并所有象限的数据
    filtered_data = pd.concat([quadrant_data[q] for q in range(1, 5) if len(quadrant_data[q]) > 0])
    
except (ImportError, OSError, RuntimeError) as e:
    print(f"\n无法加载NLP模型: {e}")
    print("使用基础方法筛选...")
    
    # 基础筛选方法
    filtered_data = pd.DataFrame()
    
    for q in range(1, 5):
        # 获取该象限的所有数据
        q_data = data[data['quadrant'] == q]
        
        if len(q_data) > 0:
            # 保留每个象限的前10-20个项目（按提及频率排序）
            limit = min(20, max(1, len(q_data)))
            q_data = q_data.sort_values('提及频率_num', ascending=False).head(limit)
            
            # 添加文本质量列（简单基于文本长度的估计）
            q_data['文本质量'] = q_data['Need'].apply(
                lambda x: min(1.0, max(0.2, len(str(x)) / 50)) if isinstance(x, str) else 0.3
            )
            
            filtered_data = pd.concat([filtered_data, q_data])

# 检查过滤后是否有数据
if len(filtered_data) == 0:
    print("警告: 过滤后没有有效的需求数据")
    create_empty_chart()
    create_empty_report()
    import sys
    sys.exit(0)

# 添加结合文本质量的最终得分
filtered_data['最终得分'] = 0.5 * filtered_data['综合得分'] + 0.5 * filtered_data['文本质量']

# 根据最终得分排序所有数据（不再按象限分别选择）
sorted_all_data = filtered_data.sort_values('最终得分', ascending=False)

# 选择前30个最高得分的项目进行可视化，确保每个象限至少有一些数据
top_n = min(30, len(filtered_data))
min_per_quadrant = min(3, max(1, len(filtered_data) // 4))  # 确保每象限最少项目，但不超过数据总量的四分之一

selected_data = pd.DataFrame()

# 先确保每个象限至少有min_per_quadrant个项目
quadrants_present = sorted_all_data['quadrant'].unique()
for q in range(1, 5):
    if q in quadrants_present:
        q_data = sorted_all_data[sorted_all_data['quadrant'] == q]
        if len(q_data) > 0:
            selected = q_data.head(min(min_per_quadrant, len(q_data)))
            selected_data = pd.concat([selected_data, selected])
            # 从sorted_all_data中移除已选择的项目
            sorted_all_data = sorted_all_data.drop(selected.index)

# 然后按得分填充剩余的位置
remaining_slots = top_n - len(selected_data)
if remaining_slots > 0 and len(sorted_all_data) > 0:
    additional = sorted_all_data.head(remaining_slots)
    selected_data = pd.concat([selected_data, additional])

# 检查最终是否有数据用于可视化
if len(selected_data) == 0:
    print("警告: 没有足够的数据进行可视化")
    create_empty_chart()
    create_empty_report()
    import sys
    sys.exit(0)

# 打印各象限选中的需求详情
print("\n## 所有象限的需求详细列表 (按最终得分排序)")
print("="*100)

quadrant_meanings = {
    1: '第一象限：核心需求区（高重要性，高频率）',
    2: '第二象限：基础需求区（低重要性，高频率）',
    3: '第三象限：潜在需求区（低重要性，低频率）',
    4: '第四象限：差异化需求区（高重要性，低频率）'
}

for q in range(1, 5):
    q_data = filtered_data[filtered_data['quadrant'] == q].sort_values('最终得分', ascending=False)
    
    if len(q_data) > 0:
        print(f"\n{quadrant_meanings[q]}")
        print("-"*100)
        
        for i, (_, row) in enumerate(q_data.iterrows()):
            print(f"{i+1}. {row['Need']}")
            print(f"   重要性分数: {row['重要性分数']:.2f}, 提及频率: {row['Frequency']}, 文本质量: {row['文本质量']:.2f}")
            print(f"   最终得分: {row['最终得分']:.2f} (综合得分: {row['综合得分']:.2f})")
            print("-"*100)

# 保存完整需求列表到文本文件
with open(needs_txt_file, 'w', encoding='utf-8') as f:
    f.write(f"# {base_filename} 用户需求象限分析 - 完整列表\n")
    f.write(f"生成时间: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
    
    for q in range(1, 5):
        q_data = filtered_data[filtered_data['quadrant'] == q].sort_values('最终得分', ascending=False)
        
        if len(q_data) > 0:
            f.write(f"\n## {quadrant_meanings[q]}\n")
            f.write(f"共有 {len(q_data)} 个需求项目\n\n")
            
            for i, (_, row) in enumerate(q_data.iterrows()):
                f.write(f"{i+1}. {row['Need']}\n")
                f.write(f"   重要性分数: {row['重要性分数']:.2f}, 提及频率: {row['Frequency']}, 文本质量: {row['文本质量']:.2f}\n")
                f.write(f"   最终得分: {row['最终得分']:.2f} (综合得分: {row['综合得分']:.2f})\n\n")

print(f"\n完整需求列表已保存到: {needs_txt_file}")

# 绘制四象限图 - 使用最终得分排序的数据
# 准备绘图数据 - 保持各象限相对位置
for q in range(1, 5):
    q_mask = selected_data['quadrant'] == q
    q_data = selected_data[q_mask]
    
    if len(q_data) == 0:
        continue
    
    # 根据象限确定目标坐标范围
    if q == 1:  # 右上
        x_range = (0.1, 0.9)
        y_range = (0.1, 0.9)
    elif q == 2:  # 左上
        x_range = (-0.9, -0.1)
        y_range = (0.1, 0.9)
    elif q == 3:  # 左下
        x_range = (-0.9, -0.1)
        y_range = (-0.9, -0.1)
    else:  # 右下
        x_range = (0.1, 0.9)
        y_range = (-0.9, -0.1)
    
    # 使用需求优先级和提及频率作为相对位置分量
    def scale_to_range(values, target_min, target_max):
        """将值缩放到目标范围内"""
        v_min = np.min(values) if len(values) > 1 else values[0]
        v_max = np.max(values) if len(values) > 1 else values[0] + 0.001
        
        # 处理边界情况
        if v_max == v_min:
            middle = (target_max + target_min) / 2
            return np.full_like(values, middle)
        
        return (values - v_min) / (v_max - v_min) * (target_max - target_min) + target_min
    
    if len(q_data) > 1:
        # 象限内有多个点时进行缩放
        selected_data.loc[q_mask, 'x_plot'] = scale_to_range(
            q_data['重要性分数'].values, 
            target_min=x_range[0], 
            target_max=x_range[1]
        )
        
        selected_data.loc[q_mask, 'y_plot'] = scale_to_range(
            q_data['提及频率_num'].values,
            target_min=y_range[0],
            target_max=y_range[1]
        )
    else:
        # 象限内只有一个点时放置在中央
        selected_data.loc[q_mask, 'x_plot'] = (x_range[0] + x_range[1]) / 2
        selected_data.loc[q_mask, 'y_plot'] = (y_range[0] + y_range[1]) / 2

# 优化标签位置，避免重叠
def optimize_label_positions(df):
    """优化标签位置，确保不重叠"""
    # 复制数据
    result = df.copy()
    
    # 根据象限将数据点分组
    quadrants = {}
    for q in range(1, 5):
        quadrants[q] = result[result['quadrant'] == q].copy()
    
    # 函数：根据象限获取边界
    def get_quadrant_bounds(q_num):
        if q_num == 1:  # 右上
            return (0.1, 0.9), (0.1, 0.9)
        elif q_num == 2:  # 左上
            return (-0.9, -0.1), (0.1, 0.9)
        elif q_num == 3:  # 左下
            return (-0.9, -0.1), (-0.9, -0.1)
        else:  # 右下
            return (0.1, 0.9), (-0.9, -0.1)
    
    # 对每个象限的数据点应用基于网格的位置优化
    for q in range(1, 5):
        q_data = quadrants[q]
        if len(q_data) == 0:
            continue
            
        x_range, y_range = get_quadrant_bounds(q)
        
        # 计算网格大小
        n_items = len(q_data)
        cols = int(np.ceil(np.sqrt(n_items)))
        rows = int(np.ceil(n_items / cols))
        
        # 计算格子大小
        cell_width = (x_range[1] - x_range[0]) / cols
        cell_height = (y_range[1] - y_range[0]) / rows
        
        # 对数据点按最终得分排序
        sorted_idx = q_data.sort_values('最终得分', ascending=False).index
        
        # 在网格中均匀放置点
        for i, idx in enumerate(sorted_idx):
            row = i // cols
            col = i % cols
            
            # 计算网格中的位置
            x = x_range[0] + cell_width * (col + 0.5)
            y = y_range[0] + cell_height * (row + 0.5)
            
            # 在第1、2象限，y坐标需要从上向下布局
            if q in [1, 2]:
                y = y_range[1] - cell_height * (row + 0.5)
            
            # 更新坐标
            result.loc[idx, 'x_plot'] = x
            result.loc[idx, 'y_plot'] = y
            
            # 记录文本长度，用于后续调整字体大小
            result.loc[idx, 'text_length'] = len(str(result.loc[idx, 'Need']))
        
    return result

# 优化标签位置
try:
    adjusted_data = optimize_label_positions(selected_data)
except Exception as e:
    print(f"优化标签位置失败: {e}")
    adjusted_data = selected_data.copy()
    if 'text_length' not in adjusted_data.columns:
        adjusted_data['text_length'] = adjusted_data['Need'].apply(lambda x: len(str(x)) if isinstance(x, str) else 0)

# 创建四象限图
plt.figure(figsize=(16, 14))  # 增大图表尺寸以容纳更多文本

# 定义象限颜色和名称
quadrant_colors = {
    1: '#FF5733',  # 红色 - 第一象限（右上）
    2: '#3373FF',  # 蓝色 - 第二象限（左上）
    3: '#33A650',  # 绿色 - 第三象限（左下）
    4: '#A633FF'   # 紫色 - 第四象限（右下）
}

quadrant_names = {
    1: '第一象限：核心需求区',
    2: '第二象限：基础需求区',
    3: '第三象限：潜在需求区',
    4: '第四象限：差异化需求区'
}

# 绘制坐标轴和网格
plt.axhline(y=0, color='gray', linestyle='-', alpha=0.3)
plt.axvline(x=0, color='gray', linestyle='-', alpha=0.3)
plt.grid(True, linestyle='--', alpha=0.3)

# 绘制数据点，尺寸根据最终得分确定
for _, row in adjusted_data.iterrows():
    q = row['quadrant']
    
    # 点的大小与最终得分成正比，范围从80到400
    point_size = 80 + 320 * row['最终得分']
    
    # 边框宽度也与得分相关
    edge_width = 1 + row['最终得分'] * 1.5
    
    plt.scatter(
        row['x_plot'], 
        row['y_plot'],
        s=point_size,  # 点的大小与最终得分成正比
        c=quadrant_colors[q],
        alpha=0.6,  # 半透明
        edgecolors='white',
        linewidth=edge_width
    )
    
    # 为每个数据点添加标签 - 只显示需求内容，不显示得分
    label = f"{row['Need']}"
    
    # 根据文本长度动态调整字体大小
    if row['text_length'] > 40:
        font_size = 8
    elif row['text_length'] > 30:
        font_size = 9
    elif row['text_length'] > 20:
        font_size = 10
    else:
        font_size = 11
    
    # 标签框样式 - 边框宽度根据得分调整
    lw = 1 + 2 * row['最终得分']
    bbox_props = dict(
        boxstyle=f"round,pad=0.5",
        fc="white", 
        ec=quadrant_colors[q], 
        alpha=0.95,
        lw=lw
    )
    
    plt.annotate(
        label, 
        (row['x_plot'], row['y_plot']),
        fontsize=font_size,
        weight='bold',
        ha='center',
        va='center',
        bbox=bbox_props
    )

# 添加象限标签名称
for q, name in quadrant_names.items():
    if q == 1:  # 右上
        pos_x, pos_y = 0.7, 0.9
    elif q == 2:  # 左上
        pos_x, pos_y = -0.7, 0.9
    elif q == 3:  # 左下
        pos_x, pos_y = -0.7, -0.9
    else:  # 右下
        pos_x, pos_y = 0.7, -0.9
    
    plt.text(
        pos_x, pos_y, name, 
        fontsize=12, 
        ha='center', 
        va='center',
        bbox=dict(
            facecolor=quadrant_colors[q], 
            alpha=0.1, 
            boxstyle='round,pad=0.6'
        )
    )

# 添加图表标题和坐标轴标签
plt.xlabel('需求优先级\n（负向：次要 | 正向：重要）', fontsize=14)
plt.ylabel('市场需求度\n（提及频率与用户关注度）', fontsize=14)
plt.title(f'{base_filename} - 未被满足的需求四象限分析', fontsize=18)

# 设置坐标轴范围
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.tight_layout()

# 保存图片
plt.savefig(output_filename, dpi=300, bbox_inches='tight')
print(f"\n图表已保存为: {output_filename}")

plt.show()
# Out:
# 当前操作系统: Windows
# 当前字体设置: ['SimHei', 'Microsoft YaHei', 'SimSun']
# 找到VOC数据文件: 致欧-2025-01-10之后VOC数据.xlsx
# 提取的文件名: 致欧-2025-01-10之后VOC数据
# 使用找到的需求分析文件: 生成结果/needs_analysis/refined_致欧-2025-01-10之后VOC数据_rating_0_to_4_length_10_to_200_words_needs_analysis.xlsx
# 成功读取数据，共361条记录
#
# 数据概览:
# 总行数: 361
# 需求列: 361 个唯一值
# 重要性分数范围: 0.7444444444444445 到 559.4510167797769
# 提及频率范围: 0.03332222592469177 到 18.99366877707431
#
# 重要性分数与提及频率的相关系数: 1.0000
#
# 对数变换后的分布:
# Log重要性分数范围: 0.56 到 6.33
# Log提及频率范围: 0.03 到 3.00
#
# 方法1: 对数变换后的中位数划分
# Log重要性分数中位数: 0.66
# Log提及频率中位数: 0.03
#
# 方法2: 25%/75%分位数划分
# 重要性分数 25%分位: 0.88, 75%分位: 0.99
# 提及频率 25%分位: 0.03, 75%分位: 0.03
# 方法3: K-means聚类映射到象限
# 聚类中心:
# 聚类 0: 重要性=53.37, 频率=1.90, 映射到象限 1
# 聚类 1: 重要性=0.97, 频率=0.04, 映射到象限 3
# 聚类 2: 重要性=352.08, 频率=12.02, 映射到象限 1
# 聚类 3: 重要性=6.29, 频率=0.24, 映射到象限 1
#
# 改进方法: 基于调整频率的主成分划分
# 回归线: adjusted_frequency = 0.0131 * log_importance + -0.0090
#
# 方法5: 多阈值分位数划分
# 重要性分数阈值: 10%=0.84, 50%=0.93, 90%=1.79
# 提及频率阈值: 10%=0.03, 50%=0.03, 90%=0.07
#
# 方法6: 强制平衡划分
# 基于数据点排名强制平均分配到四个象限
#
# 各方法象限分布对比:
#
# 对数中位数法 各象限分布:
# 象限 1: 181 项 (50.1%)
# 象限 2: 180 项 (49.9%)
# 象限 3: 0 项 (0.0%)
# 象限 4: 0 项 (0.0%)
# 标准差: 90.25, 均值: 90.25, 变异系数: 1.00
#
# 四分位数法 各象限分布:
# 有效数据点: 182/361
# 象限 1: 39 项 (10.8%)
# 象限 2: 0 项 (0.0%)
# 象限 3: 91 项 (25.2%)
# 象限 4: 52 项 (14.4%)
# 标准差: 32.50, 均值: 45.50, 变异系数: 0.71
#
# K-means聚类法 各象限分布:
# 象限 1: 22 项 (6.1%)
# 象限 2: 0 项 (0.0%)
# 象限 3: 339 项 (93.9%)
# 象限 4: 0 项 (0.0%)
# 标准差: 143.90, 均值: 90.25, 变异系数: 1.59
#
# 主成分分析法 各象限分布:
# 象限 1: 128 项 (35.5%)
# 象限 2: 180 项 (49.9%)
# 象限 3: 0 项 (0.0%)
# 象限 4: 53 项 (14.7%)
# 标准差: 68.94, 均值: 90.25, 变异系数: 0.76
#
# 多阈值分位数法 各象限分布:
# 象限 1: 181 项 (50.1%)
# 象限 2: 143 项 (39.6%)
# 象限 3: 37 项 (10.2%)
# 象限 4: 0 项 (0.0%)
# 标准差: 74.16, 均值: 90.25, 变异系数: 0.82
#
# 强制平衡法 各象限分布:
# 象限 1: 40 项 (11.1%)
# 象限 2: 141 项 (39.1%)
# 象限 3: 39 项 (10.8%)
# 象限 4: 141 项 (39.1%)
# 标准差: 50.75, 均值: 90.25, 变异系数: 0.56
#
# 选择最均衡的方法: 强制平衡法 (变异系数: 0.56)
#
# 最终选定方法各象限分布:
# 象限 1: 40 项 (11.1%)
# 象限 2: 141 项 (39.1%)
# 象限 3: 39 项 (10.8%)
# 象限 4: 141 项 (39.1%)
# 成功加载spaCy模型
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 成功加载情感分析模型
#
# 评估各象限文本质量
# 象限 1: 选择了 20 个高质量文本
# 示例:
# - needs more storage space (质量: 1.00, 提及频率: 0.02532489170276574, 重要性: 69.79)
# - could use a minimalist design (质量: 1.00, 提及频率: 0.0006664445184938354, 重要性: 1.87)
# - wish it had more tiers (质量: 0.80, 提及频率: 0.1899366877707431, 重要性: 559.45)
# 象限 2: 选择了 20 个高质量文本
# 示例:
# - could have been a lot more space in betw (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 0.91)
# - needs additional hanging space (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 0.91)
# - needed storage without taking up t (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 0.89)
# 象限 3: 选择了 20 个高质量文本
# 示例:
# - need a large shoe storage (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 0.84)
# - more like paper and i had to glue (质量: 0.90, 提及频率: 0.0003332222592469177, 重要性: 0.84)
# - would have liked to have more room betwe (质量: 0.80, 提及频率: 0.0003332222592469177, 重要性: 0.84)
# 象限 4: 选择了 20 个高质量文本
# 示例:
# - needed a space to hold my shoes an (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 0.97)
# - wish it had a shoe bag (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 1.02)
# - need a cheap shoe storage rack (质量: 1.00, 提及频率: 0.0003332222592469177, 重要性: 0.97)
#
# ## 所有象限的需求详细列表 (按最终得分排序)
# ====================================================================================================
#
# 第一象限：核心需求区（高重要性，高频率）
# ----------------------------------------------------------------------------------------------------
# 1. wish it had more tiers
#    重要性分数: 559.45, 提及频率: 0.1899366877707431, 文本质量: 0.80
#    最终得分: 0.90 (综合得分: 1.00)
# ----------------------------------------------------------------------------------------------------
# 2. could use wheels for mobility
#    重要性分数: 321.49, 提及频率: 0.109296901032989, 文本质量: 0.80
#    最终得分: 0.69 (综合得分: 0.57)
# ----------------------------------------------------------------------------------------------------
# 3. would be better if it didn't wobble
#    重要性分数: 242.54, 提及频率: 0.08263912029323559, 文本质量: 0.80
#    最终得分: 0.62 (综合得分: 0.43)
# ----------------------------------------------------------------------------------------------------
# 4. needs more storage space
#    重要性分数: 69.79, 提及频率: 0.02532489170276574, 文本质量: 1.00
#    最终得分: 0.56 (综合得分: 0.13)
# ----------------------------------------------------------------------------------------------------
# 5. could use a minimalist design
#    重要性分数: 1.87, 提及频率: 0.0006664445184938354, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 6. needs symbols of achievement
#    重要性分数: 102.14, 提及频率: 0.03465511496167944, 文本质量: 0.80
#    最终得分: 0.49 (综合得分: 0.18)
# ----------------------------------------------------------------------------------------------------
# 7. wish it was easier to assemble
#    重要性分数: 92.12, 提及频率: 0.03098967010996334, 文本质量: 0.80
#    最终得分: 0.48 (综合得分: 0.16)
# ----------------------------------------------------------------------------------------------------
# 8. needs stronger shelves
#    重要性分数: 41.94, 提及频率: 0.0149950016661113, 文本质量: 0.80
#    最终得分: 0.44 (综合得分: 0.08)
# ----------------------------------------------------------------------------------------------------
# 9. needs clearer assembly instructions
#    重要性分数: 39.07, 提及频率: 0.01332889036987671, 文本质量: 0.80
#    最终得分: 0.43 (综合得分: 0.07)
# ----------------------------------------------------------------------------------------------------
# 10. could use a top shelf
#    重要性分数: 35.42, 提及频率: 0.01232922359213596, 文本质量: 0.80
#    最终得分: 0.43 (综合得分: 0.06)
# ----------------------------------------------------------------------------------------------------
# 11. could use a polish rack
#    重要性分数: 31.96, 提及频率: 0.01066311229590137, 文本质量: 0.80
#    最终得分: 0.43 (综合得分: 0.06)
# ----------------------------------------------------------------------------------------------------
# 12. could use a night light
#    重要性分数: 18.27, 提及频率: 0.006331222925691436, 文本质量: 0.80
#    最终得分: 0.42 (综合得分: 0.03)
# ----------------------------------------------------------------------------------------------------
# 13. needs time management
#    重要性分数: 17.33, 提及频率: 0.005998000666444518, 文本质量: 0.80
#    最终得分: 0.41 (综合得分: 0.03)
# ----------------------------------------------------------------------------------------------------
# 14. would be better if it supported heavier shoes
#    重要性分数: 7.57, 提及频率: 0.002665778073975342, 文本质量: 0.80
#    最终得分: 0.41 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
# 15. needs a sturdier frame
#    重要性分数: 7.47, 提及频率: 0.002665778073975342, 文本质量: 0.80
#    最终得分: 0.41 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
# 16. would be better if it had a shoe organizer
#    重要性分数: 6.87, 提及频率: 0.002332555814728424, 文本质量: 0.80
#    最终得分: 0.41 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
# 17. could use a welcome mat
#    重要性分数: 5.10, 提及频率: 0.001666111296234589, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
# 18. needs package deals
#    重要性分数: 4.99, 提及频率: 0.001666111296234589, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
# 19. needs lower shelves
#    重要性分数: 4.78, 提及频率: 0.001666111296234589, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
# 20. wish it had a shoe tier
#    重要性分数: 4.10, 提及频率: 0.001332889036987671, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.01)
# ----------------------------------------------------------------------------------------------------
#
# 第二象限：基础需求区（低重要性，高频率）
# ----------------------------------------------------------------------------------------------------
# 1. could have been a lot more space in betw
#    重要性分数: 0.91, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 2. needs additional hanging space
#    重要性分数: 0.91, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 3. needed storage without taking up t
#    重要性分数: 0.89, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 4. more shoes than i thought it would
#    重要性分数: 0.88, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 5. could be my fault but it
#    重要性分数: 0.86, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 6. better than the one i have had for y
#    重要性分数: 0.86, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 7. needed to angle shoes sideways and
#    重要性分数: 0.93, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 8. would like to give it 3
#    重要性分数: 0.93, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 9. need a quick and somewhat cute sol
#    重要性分数: 0.93, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 10. wish it was waterproof
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 11. wish it was stackable
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 12. need a quick solution
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 13. hoped it would be more sturdy
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 14. needed but the holes in the top of
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 15. better product
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 16. could see that in the photos
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 17. need 2 people
#    重要性分数: 0.92, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 18. would be better if it reminded of shoe care
#    重要性分数: 0.91, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 19. should order this product again
#    重要性分数: 0.91, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 20. better sellers on amazon
#    重要性分数: 0.91, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
#
# 第三象限：潜在需求区（低重要性，低频率）
# ----------------------------------------------------------------------------------------------------
# 1. need a large shoe storage
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 2. more like paper and i had to glue
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 3. would have liked to have more room betwe
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 4. wish it was metal
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 5. need a hammer to make sure it was
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 6. would be fine
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 7. would have given it 5 stars had the dire
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 8. could have been a 30 minute assembly
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 9. would have trouble fitting
#    重要性分数: 0.83, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 10. more storage capacity
#    重要性分数: 0.83, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 11. could fit
#    重要性分数: 0.83, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 12. better quality
#    重要性分数: 0.82, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 13. better sturdiness
#    重要性分数: 0.82, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 14. more space for each level yet stil
#    重要性分数: 0.82, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 15. could do
#    重要性分数: 0.80, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 16. could use a spotlight
#    重要性分数: 0.80, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 17. would be nice
#    重要性分数: 0.80, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 18. needed it too
#    重要性分数: 0.79, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 19. more because a lot of people in my
#    重要性分数: 0.82, 提及频率: 0.0003332222592469177, 文本质量: 0.70
#    最终得分: 0.35 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 20. more for
#    重要性分数: 0.84, 提及频率: 0.0003332222592469177, 文本质量: 0.60
#    最终得分: 0.30 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
#
# 第四象限：差异化需求区（高重要性，低频率）
# ----------------------------------------------------------------------------------------------------
# 1. wish it had a shoe bag
#    重要性分数: 1.02, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 2. need a cheap shoe storage rack
#    重要性分数: 0.97, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 3. needed a space to hold my shoes an
#    重要性分数: 0.97, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 4. needs storage bags
#    重要性分数: 0.97, 提及频率: 0.0003332222592469177, 文本质量: 1.00
#    最终得分: 0.50 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 5. need some where to store my boots
#    重要性分数: 1.09, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 6. would be a great product to store my e
#    重要性分数: 1.04, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 7. want to waste my time with a replac
#    重要性分数: 0.99, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 8. better than the other item i bought
#    重要性分数: 0.98, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 9. needs for what we bought it for bu
#    重要性分数: 0.95, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 10. wish i didn
#    重要性分数: 0.95, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 11. would like to return this product but i
#    重要性分数: 0.95, 提及频率: 0.0003332222592469177, 文本质量: 0.90
#    最终得分: 0.45 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 12. would be better if it paired shoes together
#    重要性分数: 1.15, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 13. could give this pos negative 100 sta
#    重要性分数: 1.13, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 14. could use a tier system
#    重要性分数: 1.08, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 15. should take responsibility for their
#    重要性分数: 1.07, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 16. need tools to make adjustments to
#    重要性分数: 1.07, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 17. need a refund it
#    重要性分数: 1.06, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 18. needle nose to bend most of the en
#    重要性分数: 1.06, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 19. needed 12 thumb screws to assemble
#    重要性分数: 1.05, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
# 20. needed to effectively frame the ra
#    重要性分数: 1.05, 提及频率: 0.0003332222592469177, 文本质量: 0.80
#    最终得分: 0.40 (综合得分: 0.00)
# ----------------------------------------------------------------------------------------------------
#
# 完整需求列表已保存到: 生成结果/needs_analysis/致欧-2025-01-10之后VOC数据_用户需求象限分析_完整列表.txt
# 图表已保存为: 生成结果/needs_analysis/致欧-2025-01-10之后VOC数据_用户需求四象限分析_综合得分版.png
